# %%
import akshare as ak

ak.__version__
# Out:
# '1.18.49'

# %%
#gz_df = ak.index_all_cni().set_index('指数代码')
ak.index_all_cni()
# Out:
#           指数代码          指数简称  样本数        收盘点位     涨跌幅     PE滚动           成交量  \
# 0       399001          深证成指  500  13760.3690  0.0113  26.0317  204452.38065
# 1       399002          深成指R  500  18483.5785  0.0113  26.0317  204452.38065
# 2       399003          成份Ｂ指   10   7817.3428  0.0026   7.5718      75.13949
# 3       399004        深证100R  100   8304.5263  0.0085  22.4382   47915.59880
# 4       399005         中小100  100   8360.2417  0.0130  24.4848   41346.39891
# ...        ...           ...  ...         ...     ...      ...           ...
# 1401  CNB20012  国证政金5-10(全价)    0         NaN     NaN      NaN           NaN
# 1402  CNB20013   高等级绿色债券（全价）    0         NaN     NaN      NaN           NaN
# 1403  CNB20014  高等级非贴标绿债（全价）    0         NaN     NaN      NaN           NaN
# 1404  CNB20015   高等级贴标绿债（全价）    0         NaN     NaN      NaN           NaN
# 1405   RETHKDG    中华房地产信托基金R   30   2976.7586  0.0076      NaN     189.12459
#
# ...
