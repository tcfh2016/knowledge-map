# %%
import akshare as ak

ak.__version__
# Out:
# '1.18.19'

# %%
#gz_df = ak.index_all_cni().set_index('指数代码')
ak.index_all_cni()
# Out:
#           指数代码          指数简称  样本数        收盘点位     涨跌幅     PE滚动           成交量  \
# 0       399001          深证成指  500  14439.6584  0.0079  27.1426  357982.58762
# 1       399002          深成指R  500  19392.1389  0.0081  27.1426  357982.58762
# 2       399003          成份Ｂ指   10   8173.7910  0.0060   8.0400     114.54013
# 3       399004        深证100R  100   8391.8015 -0.0045  22.7149   81817.29579
# 4       399005         中小100  100   8883.3326  0.0069  25.8180   81265.16699
# ...        ...           ...  ...         ...     ...      ...           ...
# 1386  CNB20012  国证政金5-10(全价)    0         NaN     NaN      NaN           NaN
# 1387  CNB20013   高等级绿色债券（全价）    0         NaN     NaN      NaN           NaN
# 1388  CNB20014  高等级非贴标绿债（全价）    0         NaN     NaN      NaN           NaN
# 1389  CNB20015   高等级贴标绿债（全价）    0         NaN     NaN      NaN           NaN
# 1390   RETHKDG    中华房地产信托基金R   30   3094.9578 -0.0024      NaN     278.10417
#
# ...
