# %% [markdown]
# ## 获取A股多个估值指标

# %%
import pandas as pd
import akshare as ak

indicator_dfs = []
for ind in ['总市值', '市盈率(TTM)']:
    df = ak.stock_zh_valuation_baidu(symbol='002044', indicator=ind, period='近一年')
    df = df.set_index('date').rename(columns={'value':ind})
    indicator_dfs.append(df)

pd.concat(indicator_dfs, axis=1)
# Out:
#                总市值  市盈率(TTM)
# date
# 2023-05-05  266.17    -98.86
# 2023-05-06  266.17    -98.86
# 2023-05-07  266.17    -98.86
# 2023-05-08  263.82    -97.99
# 2023-05-09  263.82    -97.99
# ...            ...       ...
# 2024-04-30  173.01     44.80
# 2024-05-01  173.01     44.80
# 2024-05-02  173.01     44.80
# 2024-05-03  173.01     44.80
# 2024-05-04  173.01     44.80
#
# [366 rows x 2 columns]

# %% [markdown]
# ## 获取港股多个估值指标

# %%
import pandas as pd
import akshare as ak
import matplotlib.pyplot as plt

plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.sans-serif'] = ['SimHei']

indicator_dfs = []
for ind in ['总市值', '市盈率(TTM)', '市净率']:
    df = ak.stock_hk_valuation_baidu(symbol='00700', indicator=ind, period='全部')
    df = df.set_index('date').rename(columns={'value':ind})
    indicator_dfs.append(df)

df = pd.concat(indicator_dfs, axis=1)
df.plot(figsize=(12, 9), secondary_y=['市盈率(TTM)', '市净率'])
# Out:
# <Axes: xlabel='date'>
