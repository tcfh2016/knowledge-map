# %% [markdown]
# # A股估值指标

# %% [markdown]
# ## 市值、市盈率、市净率

# %%
import pandas as pd
import akshare as ak
import matplotlib.pyplot as plt

plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.sans-serif'] = ['SimHei']

indicator_dfs = []
for ind in ['总市值', '市盈率(TTM)', '市净率']:
    df = ak.stock_zh_valuation_baidu(symbol='603259', indicator=ind, period='全部')
    df = df.set_index('date').rename(columns={'value':ind})
    indicator_dfs.append(df)

df = pd.concat(indicator_dfs, axis=1)
df.plot(figsize=(6, 3), secondary_y=['市盈率(TTM)', '市净率'])
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# # 港股估值指标

# %% [markdown]
# ## 市值、市盈率

# %%
import pandas as pd
import akshare as ak
import matplotlib.pyplot as plt

plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.sans-serif'] = ['SimHei']

indicator_dfs = []
for ind in ['总市值', '市盈率(TTM)']:
    df = ak.stock_hk_valuation_baidu(symbol='09626', indicator=ind, period='全部')
    df = df.set_index('date').rename(columns={'value':ind})
    indicator_dfs.append(df)

df = pd.concat(indicator_dfs, axis=1)
df.plot(figsize=(10, 5), secondary_y=['市盈率(TTM)'])
# Out:
# <Axes: xlabel='date'>

# %%
df["总市值"].head()
# Out:
# date
# 2021-03-30    3018.48
# 2021-04-01    3282.60
# 2021-04-03    3282.60
# 2021-04-05    3282.60
# 2021-04-07    3297.69
# Name: 总市值, dtype: float64

# %%
indicator_dfs = []
for ind in ['总市值', '市盈率(TTM)']:
    df = ak.stock_hk_valuation_baidu(symbol='09988', indicator=ind, period='全部')
    df = df.set_index('date').rename(columns={'value':ind})
    indicator_dfs.append(df)

df = pd.concat(indicator_dfs, axis=1)
df.plot(figsize=(4, 3), secondary_y=['市盈率(TTM)'])
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# # 港股公司市值对比

# %%
df = ak.stock_hk_valuation_baidu(symbol='09988', indicator='总市值', period='全部')
df['date'] = pd.to_datetime(df['date'])
df = df[df['date'] > '2019-11-27']
df
# Out:
#           date     value
# 1   2019-11-30  42431.38
# 2   2019-12-03  41190.95
# 3   2019-12-06  42387.02
# 4   2019-12-09  42193.87
# 5   2019-12-12  42966.49
# ..         ...       ...
# 760 2026-02-23  29069.14
# 761 2026-02-26  27312.00
# 762 2026-03-01  27292.90
# 763 2026-03-04  24809.99
# 764 2026-03-07  24962.79
#
# [764 rows x 2 columns]

# %%
indicator_dfs = []
#stocks = ['00700', '09988']
stocks = ['00700']
for sym in stocks:
    df = ak.stock_hk_valuation_baidu(symbol=sym, indicator='总市值', period='全部')
    df = df.set_index('date').rename(columns={'value':sym})
    indicator_dfs.append(df)

#df = pd.concat(indicator_dfs, axis=1)
#df.plot(figsize=(12, 9), secondary_y=['市盈率(TTM)'])

# %% [markdown]
# ## 韭圈儿

# %%
ak.index_value_hist_funddb(symbol='000001').astype({'日期':str})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 ak.index_value_hist_funddb(symbol='000001').astype({'日期':str})
#
# AttributeError: module 'akshare' has no attribute 'index_value_hist_funddb'
