# %% [markdown]
# step 1: 导入函数库

# %%
import pandas as pd

# %% [markdown]
# step 2: 读取csv文件

# %%
df = pd.read_csv("002027.csv")
print(df)
# Out:
#              day         code    pe_ratio  pb_ratio  market_cap
# 0     2016-01-04  002027.XSHE  55118.3437    3.9036   1576.3864
# 1     2016-01-05  002027.XSHE  51016.8482    3.6132   1459.0835
# 2     2016-01-06  002027.XSHE  53621.6576    3.7976   1533.5812
# 3     2016-01-07  002027.XSHE  48253.7354    3.4175   1380.0583
# 4     2016-01-08  002027.XSHE  46915.3526    3.3227   1341.7806
# ...          ...          ...         ...       ...         ...
# 1628  2022-09-09  002027.XSHE     17.8062    4.1025    813.0958
# 1629  2022-09-13  002027.XSHE     18.0275    4.1535    823.2054
# 1630  2022-09-14  002027.XSHE     17.8062    4.1025    813.0958
# 1631  2022-09-15  002027.XSHE     17.6164    4.0587    804.4305
# 1632  2022-09-16  002027.XSHE     17.0155    3.9203    776.9903
#
# [1633 rows x 5 columns]

# %% [markdown]
# step 3: 读取csv文件，指定行标签

# %%
df = pd.read_csv("002027.csv", index_col=0)
print(df)
# Out:
#                    code    pe_ratio  pb_ratio  market_cap
# day
# 2016-01-04  002027.XSHE  55118.3437    3.9036   1576.3864
# 2016-01-05  002027.XSHE  51016.8482    3.6132   1459.0835
# 2016-01-06  002027.XSHE  53621.6576    3.7976   1533.5812
# 2016-01-07  002027.XSHE  48253.7354    3.4175   1380.0583
# 2016-01-08  002027.XSHE  46915.3526    3.3227   1341.7806
# ...                 ...         ...       ...         ...
# 2022-09-09  002027.XSHE     17.8062    4.1025    813.0958
# 2022-09-13  002027.XSHE     18.0275    4.1535    823.2054
# 2022-09-14  002027.XSHE     17.8062    4.1025    813.0958
# 2022-09-15  002027.XSHE     17.6164    4.0587    804.4305
# 2022-09-16  002027.XSHE     17.0155    3.9203    776.9903
#
# [1633 rows x 4 columns]

# %%
p = df.plot(y='market_cap', figsize=(10,5))
print(p.figure.figure)
# Out:
# Figure(2000x500)

# %% [markdown]
# step 4: 使用plot()画图
